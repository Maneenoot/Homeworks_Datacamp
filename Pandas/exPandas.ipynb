# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1.โหลด csv เข้าไปใน Python Pandas

# %%
url = 'https://raw.githubusercontent.com/Maneenoot/Datasets/master/Data%20Set/Titanic_dataset/train.csv'
df = pd.read_csv(url, error_bad_lines=False)
df
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 0             75         1       3                              Bing, Mr. Lee
# 1            205         1       3                   Cohen, Mr. Gurshon "Gus"
# 2            234         1       3             Asplund, Miss. Lillian Gertrud
# 3            634         0       1              Parr, Mr. William Henry Marsh
# 4            844         0       3                 Lemberopolous, Mr. Peter L
# ..           ...       ...     ...                                        ...
# 707          145         0       2                 Andrew, Mr. Edgardo Samuel
# 708          614         0       3                           Horgan, Mr. John
# 709          578         1       1  Silvey, Mrs. William Baird (Alice Munger)
# 710          702         1       1           Silverthorne, Mr. Spencer Victor
# 711          510         1       3                             Lang, Mr. Fang
#
# ...

# %% [markdown]
# ## 2.เขียนโค้ดแสดง หัว10แถว ท้าย10แถว และสุ่ม10แถว

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0           75         1       3                   Bing, Mr. Lee    male
# 1          205         1       3        Cohen, Mr. Gurshon "Gus"    male
# 2          234         1       3  Asplund, Miss. Lillian Gertrud  female
# 3          634         0       1   Parr, Mr. William Henry Marsh    male
# 4          844         0       3      Lemberopolous, Mr. Peter L    male
# 5          389         0       3            Sadlier, Mr. Matthew    male
# 6          757         0       3    Carlsson, Mr. August Sigfrid    male
# 7          450         1       1  Peuchen, Major. Arthur Godfrey    male
# 8          408         1       2  Richards, Master. William Rowe    male
# 9          787         1       3       Sjoblom, Miss. Anna Sofia  female
#
#     Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 0  32.0      0      0      1601  56.4958   NaN        S
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 702          768         0       3
# 703          618         0       3
# 704          430         1       3
# 705           49         0       3
# 706          632         0       3
# 707          145         0       2
# 708          614         0       3
# 709          578         1       1
# 710          702         1       1
# 711          510         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 702                               Mangan, Miss. Mary  female  30.5      0
# 703  Lobb, Mrs. William Arthur (Cordelia K Stanlick)  female  26.0      1
# 704               Pickard, Mr. Berk (Berk Trembisky)    male  32.0      0
# 705                              Samaan, Mr. Youssef    male   NaN      2
# 706                      Lundahl, Mr. Johan Svensson    male  51.0      0
# 707                       Andrew, Mr. Edgardo Samuel    male  18.0      0
# ...

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 86           319         1       1
# 516          373         0       3
# 519          697         0       3
# 495          435         0       1
# 640          814         0       3
# 553          875         1       2
# 669          853         0       3
# 217          286         0       3
# 692          162         1       2
# 116          414         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 86                            Wick, Miss. Mary Natalie  female  31.0      0
# 516                         Beavan, Mr. William Thomas    male  19.0      0
# 519                                   Kelly, Mr. James    male  44.0      0
# 495                          Silvey, Mr. William Baird    male  50.0      1
# 640                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 553              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# ...

# %%
#3 ลบ row ที่มี Embarked ว่าง
df['Embarked'].dropna()
# Out:
# 0      S
# 1      S
# 2      S
# 3      S
# 4      C
#       ..
# 707    S
# 708    Q
# 709    S
# 710    S
# 711    S
# Name: Embarked, Length: 710, dtype: object

# %%
#4 เติม age ด้วยค่าเฉลี่ย
avg = df['Age'].mean()
df['Age'].fillna(value = avg)
# Out:
# 0      32.000000
# 1      18.000000
# 2       5.000000
# 3      29.704806
# 4      34.500000
#          ...
# 707    18.000000
# 708    29.704806
# 709    39.000000
# 710    35.000000
# 711    26.000000
# Name: Age, Length: 712, dtype: float64

# %%
# 5เติม age ด้วย0
df['Age'].fillna(value = 0)
# Out:
# 0      32.0
# 1      18.0
# 2       5.0
# 3       0.0
# 4      34.5
#        ...
# 707    18.0
# 708     0.0
# 709    39.0
# 710    35.0
# 711    26.0
# Name: Age, Length: 712, dtype: float64

# %%
#6 ลบ row ที่ age เป็นค่าว่าง
df['Age'].dropna()
# Out:
# 0      32.0
# 1      18.0
# 2       5.0
# 4      34.5
# 6      28.0
#        ...
# 706    51.0
# 707    18.0
# 709    39.0
# 710    35.0
# 711    26.0
# Name: Age, Length: 566, dtype: float64

# %%
#7 หาจำนวนผู้หญิงต่อผู้ชายที่อยู่บนเรือ
df['Sex'].value_counts()
# Out:
# 1    459
# 0    253
# Name: Sex, dtype: int64

# %%
print('จำนวน ผญ/ผช บนเรือ : {:.2f}'.format(459/253))
# Out:
# จำนวน ผญ/ผช บนเรือ : 1.81

# %%
#8 หาจำนวนผู้หญิงและผู้ชายที่รอดชีวิต
df['Survived'].value_counts()
# Out:
# 0    439
# 1    273
# Name: Survived, dtype: int64

# %%
#9 หา % การรอดชีวิตของผู้หญิงและผู้ชาย

df['Survived'].value_counts()/len(df)
# Out:
# 0    0.616573
# 1    0.383427
# Name: Survived, dtype: float64

# %%
#9
#sum = df['Survived'].sum()
df['Survived'].value_counts()/len(df['Survived'])
# Out:
# 0    0.616573
# 1    0.383427
# Name: Survived, dtype: float64

# %%
#10 แปลงคอลัมน์ female = 0 และ male = 1
condition = (df['Sex'] == 'male')
df['Sex'] = np.where(condition,1,0)

# %%
#11 หาคนที่อายุมากที่สุดพร้อมบอกชื่อ อายุ และลงท่าที่ไหน
max1 = df['Age'].max()
rslt_df = df[df['Age'] == max1] 
rslt_df
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 180          631         1       1  Barkworth, Mr. Algernon Henry Wilson    1
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 180  80.0      0      0  27042  30.0   A23        S

# %%
#12 หาคนที่อายุน้อยที่สุดพร้อมบอกชื่อ อายุ และลงท่าที่ไหน
min1 = df['Age'].min()
rslt_df = df[df['Age'] == min1] 
rslt_df
# Out:
#      PassengerId  Survived  Pclass                             Name  Sex  \
# 592          804         1       3  Thomas, Master. Assad Alexander    1
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 592  0.42      0      1   2625  8.5167   NaN        C

# %%
#13 หาคนที่จ่ายค่าโดยสารแพงที่สุดพร้อมบอกชื่อ อายุ และ รอดชีวิตไหม
Pmax1 = df['Fare'].max()
rslt_df = df[df['Fare'] == Pmax1] 
rslt_df
# Out:
#      PassengerId  Survived  Pclass                                Name  Sex  \
# 70           259         1       1                    Ward, Miss. Anna    0
# 354          738         1       1              Lesurer, Mr. Gustave J    1
# 530          680         1       1  Cardeza, Mr. Thomas Drake Martinez    1
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 70   35.0      0      0  PC 17755  512.3292          NaN        C
# 354  35.0      0      0  PC 17755  512.3292         B101        C
# 530  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C

# %%
#14 หาคนที่จ่ายค่าโดยสารถูกที่สุดพร้อมบอกชื่อ อายุ และรอดชีวิตไหม
Lmin1 = df['Fare'].min()
rslt_df = df[df['Fare'] == Lmin1] 
rslt_df
# Out:
#      PassengerId  Survived  Pclass                              Name  Sex  \
# 3            634         0       1     Parr, Mr. William Henry Marsh    1
# 116          414         0       2    Cunningham, Mr. Alfred Fleming    1
# 121          823         0       1   Reuchlin, Jonkheer. John George    1
# 125          816         0       1                  Fry, Mr. Richard    1
# 169          272         1       3      Tornquist, Mr. William Henry    1
# 175          807         0       1            Andrews, Mr. Thomas Jr    1
# 262          675         0       2        Watson, Mr. Ennis Hastings    1
# 295          467         0       2             Campbell, Mr. William    1
# 315          482         0       2  Frost, Mr. Anthony Wood "Archie"    1
# 461          598         0       3               Johnson, Mr. Alfred    1
# 479          180         0       3               Leonard, Mr. Lionel    1
# 589          278         0       2       Parkes, Mr. Francis "Frank"    1
# ...

# %%
 #15 สรุปว่ามีคนนั่งตั๋ว 1 2 3 กี่คน
df.groupby(['Pclass']).describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std   min     25%    50%    75%    max
# Pclass
# 1            172.0  471.191860  247.016853   4.0  273.25  486.0  684.0  890.0
# 2            157.0  449.324841  248.284711  10.0  235.00  441.0  667.0  887.0
# 3            383.0  439.859008  261.329486   1.0  206.50  425.0  660.0  891.0
#
#        Survived            ... Parch        Fare                             \
#           count      mean  ...   75%  max  count       mean        std  min
# Pclass                     ...
# 1         172.0  0.627907  ...   1.0  4.0  172.0  85.216086  83.537291  0.0
# 2         157.0  0.496815  ...   1.0  3.0  157.0  20.535616  13.768942  0.0
# 3         383.0  0.227154  ...   0.0  6.0  383.0  13.873725  12.110538  0.0
#
#
#             25%      50%      75%       max
# Pclass
# 1       30.6958  57.9792  90.2698  512.3292
# 2       12.6500  13.7917  26.0000   73.5000
# ...

# %%
#16 หาค่าเฉลี่ยของตั๋วโดยสารแบบที่นั่งชั้น 1 2 3
T_01 = df.loc[(df['Pclass'] == 1)]
T_02 = T_01.mean()
T_03 = T_02['Fare']
print('ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: {:.2f}'.format(T_03))
# Out:
# ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: 85.22

# %%
T_21 = df.loc[(df['Pclass'] == 2)]
T_22 = T_21.mean()
T_23 = T_22['Fare']
print('ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: {:.2f}'.format(T_23))
# Out:
# ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: 20.54

# %%
T_31 = df.loc[(df['Pclass'] == 3)]
T_32 = T_31.mean()
T_33 = T_32['Fare']
print('ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: {:.2f}'.format(T_33))
# Out:
# ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: 13.87

# %%
#17 มีผู้โดยสารกี่คนที่อายุเกิน 50 แล้วรอดชีวิต
df_17 = (df['Age'] > 50) & (df['Survived'] == 1)
df_117 = df_17.value_counts()
df_117
# Out:
# False    696
# True      16
# dtype: int64

# %%
#17.1
print('16')
# Out:
# 16

# %%
#18 แสดงผลข้อมูลทั้งหมดของที่นั่งชั้น 1 2 3 (describe)
df.groupby(['Pclass']).describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std   min     25%    50%    75%    max
# Pclass
# 1            172.0  471.191860  247.016853   4.0  273.25  486.0  684.0  890.0
# 2            157.0  449.324841  248.284711  10.0  235.00  441.0  667.0  887.0
# 3            383.0  439.859008  261.329486   1.0  206.50  425.0  660.0  891.0
#
#        Survived            ... Parch        Fare                             \
#           count      mean  ...   75%  max  count       mean        std  min
# Pclass                     ...
# 1         172.0  0.627907  ...   1.0  4.0  172.0  85.216086  83.537291  0.0
# 2         157.0  0.496815  ...   1.0  3.0  157.0  20.535616  13.768942  0.0
# 3         383.0  0.227154  ...   0.0  6.0  383.0  13.873725  12.110538  0.0
#
#
#             25%      50%      75%       max
# Pclass
# 1       30.6958  57.9792  90.2698  512.3292
# 2       12.6500  13.7917  26.0000   73.5000
# ...

# %%
#19 แสดงผลตั๋วที่แพงที่สุดของที่นั่งแต่ละชั้น
T_01 = df.loc[(df['Pclass'] == 1)]
T_02 = T_01.max()
T_03 = T_02['Fare']
print('ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: {:.2f}'.format(T_03))
# Out:
# ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: 512.33

# %%
#19
T_21 = df.loc[(df['Pclass'] == 2)]
T_22 = T_21.max()
T_23 = T_22['Fare']
print('ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: {:.2f}'.format(T_23))
# Out:
# ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: 73.50

# %%
#19
T_31 = df.loc[(df['Pclass'] == 3)]
T_32 = T_31.max()
T_33 = T_32['Fare']
print('ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: {:.2f}'.format(T_33))
# Out:
# ค่าเฉลี่ยของตั๋วโดยสารชั้นที่1: 69.55

# %%
#20 แสดงเป็นกลุ่มช่วงอายุ 0-10, 20-30 …. (เพิ่มทีละ10) และหา ว่าแต่ละกลุ่มมีอัตราการรอดชีวิตเท่าไหร่

# %%
#21 เรียงลำดับตามราคามากไปน้อย และน้อยไปมาก
df['Fare'].sort_values()
# Out:
# 116      0.0000
# 125      0.0000
# 634      0.0000
# 461      0.0000
# 479      0.0000
#          ...
# 240    263.0000
# 231    263.0000
# 530    512.3292
# 70     512.3292
# 354    512.3292
# Name: Fare, Length: 712, dtype: float64

# %%
#21 
df['Fare'].sort_values(ascending=False)
# Out:
# 354    512.3292
# 70     512.3292
# 530    512.3292
# 231    263.0000
# 240    263.0000
#          ...
# 479      0.0000
# 461      0.0000
# 634      0.0000
# 125      0.0000
# 116      0.0000
# Name: Fare, Length: 712, dtype: float64

# %%
#22 (Optional) หานามสกุลที่ซ้ำกัน และแต่ละนามสกุลที่ซ้ำกันซ้ำกันกี่คน

# %%
#23. (Optional) แสดงผลนามสกุลที่ไม่มีการซ้ำกันเลย และนับว่ามีกี่นามสกุล
#23 แยกเนม และเซเนม สร้าง ฟีลเจอใหม่ โดยคอมม่า แล้วค่อยแยกนับที่ไม่ซำ้
df['Sname'] = df['Name'].
df['Lname'] = df['Name'].

# %%
txt = df[['Name']]
x = txt.split(", ")
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-35bac73220ef> in <module>
#       1 txt = df[['Name']]
# ----> 2 x = txt.split(", ")
#       3 print(x)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
txt = "hello, my name is Peter, I am 26 years old"
x = txt.split(", ")
print(x)
# Out:
# ['hello', 'my name is Peter', 'I am 26 years old']
